# %%
from QKD_routing import init, main, main_sksh

# %%
# Parameters of routing procedure
max_key_rate = 100
nodes = 4
dlt = 1.0
init_pars = init(max_key_rate, nodes)

# %%
# Routing without secret sharing
main(init_pars, dlt)
# Out:
# -------------------------step 0-------------------------
# sender, reciever:  1 2
# all the paths:  [[1, 0, 2], [1, 0, 3, 2], [1, 2], [1, 3, 0, 2], [1, 3, 2]]
# choosed path:  [1, 3, 0, 2]
# the situation before running 51.951322565250166
# dlt 1.0
# R:
#  [[ 0.         49.03243362 49.59531302 33.24156988]
#  [49.03243362  0.          6.86366744 55.81499   ]
#  [49.59531302  6.86366744  0.         66.87494097]
#  [33.24156988 55.81499    66.87494097  0.        ]]
# D:
#  [[  0.         -11.96756638  19.59531302  32.24156988]
#  [-11.96756638   0.         -49.13633256   2.81499   ]
#  [ 19.59531302 -49.13633256   0.          27.87494097]
#  [ 32.24156988   2.81499     27.87494097   0.        ]]
# -------------------------step 1-------------------------
# sender, reciever:  1 2
# all the paths:  [[1, 0, 2], [1, 0, 3, 2], [1, 2], [1, 3, 0, 2], [1, 3, 2]]
# choosed path:  [1, 3, 0, 2]
# the situation before running 49.951322565250166
# dlt 1.0
# R:
# ...

# %%
# Routing with secret sharing
privacy_coef = 2
main_sksh(init_pars, dlt, privacy_coef)
# Out:
# -------------------------step 0-------------------------
# sender, reciever:  1 2
# all the paths:  [[1, 0, 2], [1, 0, 3, 2], [1, 2], [1, 3, 0, 2], [1, 3, 2]]
# choosed paths:  [[1, 0, 2], [1, 0, 2]]
# the situation before running 19.429636314965393
# dlt 1.0
# R:
#  [[ 0.         40.57036369 18.64399046 11.24156988]
#  [40.57036369  0.         37.57036369 33.57036369]
#  [18.64399046 37.57036369  0.         66.63031466]
#  [11.24156988 33.57036369 66.63031466  0.        ]]
#  privacy:
#  0
# the situation before running 19.429636314965393
# dlt 1.0
# R:
#  [[ 0.         39.57036369 17.64399046 11.24156988]
#  [39.57036369  0.         38.57036369 33.57036369]
#  [17.64399046 38.57036369  0.         66.63031466]
#  [11.24156988 33.57036369 66.63031466  0.        ]]
#  privacy:
#  1
# D:
#  [[  0.         -21.42963631 -12.35600954  10.24156988]
#  [-21.42963631   0.         -17.42963631 -19.42963631]
#  [-12.35600954 -17.42963631   0.          27.63031466]
# ...
